# %% [markdown]
# ## Fonte de Dados
# https://www.kaggle.com/datasets/kabure/german-credit-data-with-risk/metadata

# %% [markdown]
# ## Instalação e Carga de Pacotes:

# %%
# Versão da Linguagem Python
from platform import python_version
print('Versão da Linguagem Python Utilizada:', python_version())
# Out:
# Versão da Linguagem Python Utilizada: 3.10.4

# %%
# Filtro de warnings
import warnings
warnings.simplefilter(action='ignore', category=FutureWarning)
warnings.simplefilter(action='ignore', category=UserWarning)

# %%
# Imports
import os
import copy 
import json
import statistics
import tensorflow              as     tf
import autokeras               as     ak
import numpy                   as     np
import pandas                  as     pd
import matplotlib.pyplot       as     plt 
import seaborn                 as     sns
from   sklearn.model_selection import train_test_split
from   sklearn.metrics         import accuracy_score, f1_score
import logging

logging.getLogger('tensorflow').disabled = True
# Out:
# 2022-08-16 16:24:10.597546: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcudart.so.11.0'; dlerror: libcudart.so.11.0: cannot open shared object file: No such file or directory
# 2022-08-16 16:24:10.597567: I tensorflow/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.

# %%
# Versões dos pacotes usados neste jupyter notebook
# %reload_ext watermark
# %watermark -a "Pedro G. Dubiela" --iversions
# Out:
# Author: Pedro G. Dubiela
#
# json      : 2.0.9
# seaborn   : 0.11.2
# statistics: 1.0.3.5
# matplotlib: 3.5.2
# tensorflow: 2.9.1
# logging   : 0.5.1.2
# autokeras : 1.0.19
# numpy     : 1.23.1
# pandas    : 1.4.3

# %% [markdown]
# ## Carga e Exploração dos Dados

# %%
# Carregando os arquivos
df_original = pd.read_csv("./german_credit_data.csv")
df = copy.deepcopy(df_original)

# %%
# Alterando nome da coluna Unnamed
df.rename(columns = {"Unnamed: 0":"ID"}, inplace = True)

# %%
# Procurando por valores faltantes:
# Existem valores missing nas colunas Saving accounts e Checking account
df.isnull().any()
# Out:
# ID                  False
# Age                 False
# Sex                 False
# Job                 False
# Housing             False
# Saving accounts      True
# Checking account     True
# Credit amount       False
# Duration            False
# Purpose             False
# Risk                False
# dtype: bool

# %%
# 47% dos registros possuem campos missing, vamos substituir pela moda
df[df.isnull().T.any()].shape[0] / df.shape[0]

# Substituir pela moda
colnames = ["Saving accounts", "Checking account"]
for name in colnames:
    df.loc[df[name].isnull(), [name]] = statistics.mode(df[name][df[name].notnull()])

# %%
# Avaliando se as classes estão desbalanceadas:
df[["ID", "Risk"]].groupby("Risk").count()

#df_class_bad   = df[df["Risk"] == "bad"]
#df_class_good  = df[df["Risk"] == "good"]
#df_class_good2 = df_class_good.sample(df_class_bad.shape[0])
#df             = pd.concat([df_class_bad, df_class_good2], axis = 0)
# Out:
#        ID
# Risk
# bad   300
# good  700

# %%
# Dividino entre treino e teste
y = df.pop("Risk")
X = df
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.2)

# %% [markdown]
# ## Modelagem via AutoML

# %%
# Cria o objeto de busca de modelos (vamos testar 3 modelos diferentes)
clf = ak.StructuredDataClassifier(overwrite = True, max_trials = 100)

# %%
# Treina o objeto definindo qual é a classe (variável target)
clf.fit(X_train, y_train)
# Out:
# Trial 35 Complete [00h 00m 03s]
# val_accuracy: 0.706250011920929
#
# Best val_accuracy So Far: 0.71875
# Total elapsed time: 00h 04m 07s
# 25/25 [==============================] - 0s 1ms/step - loss: 0.6769 - accuracy: 0.5825

# %%
# Sumário do modelo
model = clf.export_model()
model.summary()
# Out:
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 10)]              0
#
#  multi_category_encoding (Mu  (None, 10)               0
#  ltiCategoryEncoding)
#
#  normalization (Normalizatio  (None, 10)               21
#  n)
#
#  dense (Dense)               (None, 32)                352
#
#  re_lu (ReLU)                (None, 32)                0
#
#  dense_1 (Dense)             (None, 32)                1056
#
#  re_lu_1 (ReLU)              (None, 32)                0
#
#  dense_2 (Dense)             (None, 32)                1056
#
#  re_lu_2 (ReLU)              (None, 32)                0
#
#  dropout (Dropout)           (None, 32)                0
#
#  dense_3 (Dense)             (None, 1)                 33
#
#  classification_head_1 (Acti  (None, 1)                0
#  vation)
#
# =================================================================
# Total params: 2,518
# Trainable params: 2,497
# Non-trainable params: 21
# _________________________________________________________________

# %% [markdown]
# ## Avaliação do Modelo nos Dados de Teste

# %%
# Previsões com o melhor modelo
yp = clf.predict(X_test)
# Out:
# 7/7 [==============================] - 0s 1ms/step
# 7/7 [==============================] - 0s 1ms/step

# %%
# Avaliação do modelo
accuracy_score(y_test, yp)
# Out:
# 0.73

# %%
# Função para visualizar o resultado do AutoML
def imprimeTabela(path = 'structured_data_classifier'):
    
    # Abre o arquivo json de cada trial
    trial_json = os.popen('ls ./{}/trial_*/trial.json'.format(path)).read().split('\n')[:-1]
    
    # Lista para os dados
    DATA = []
    
    # Loop pelo arquivo json para alimentar a lista DATA
    for file in trial_json:
        with open(file) as f: 
            DATA.append(json.load(f))
    
    # Separa a lista pelos campos
    for k in range(len(DATA)):
        DATA[k]['hyperparameters']['values']['score'] = DATA[k]['score']
    
    # Cria o dataframe
    hyper_df = pd.concat([pd.DataFrame.from_dict(data['hyperparameters']['values'], orient = 'index') for data in DATA], axis=1)
    
    # Gera as colunas
    hyper_df.columns = ["trial#{}".format(k+1) for k in range(len(DATA))]
    
    return(hyper_df)

# %%
# Comparativo entre todas as tentativas:
display(imprimeTabela())
# Out:
#                                                     trial#1 trial#2 trial#3  \
# structured_data_block_1/normalize                      True    True    True
# structured_data_block_1/dense_block_1/num_layers          2       2       3
# structured_data_block_1/dense_block_1/use_batch...    False   False   False
# structured_data_block_1/dense_block_1/dropout             0       0       0
# structured_data_block_1/dense_block_1/units_0            32      32      32
# structured_data_block_1/dense_block_1/units_1            32      32      32
# classification_head_1/dropout                           0.0     0.0     0.0
# optimizer                                              adam    adam    adam
# learning_rate                                         0.001   0.001   0.001
# score                                               0.70625     0.7  0.7125
# structured_data_block_1/dense_block_1/units_2           NaN     NaN      32
#
#                                                     trial#4  trial#5  trial#6  \
# structured_data_block_1/normalize                      True     True     True
# structured_data_block_1/dense_block_1/num_layers          3        3        3
# structured_data_block_1/dense_block_1/use_batch...    False    False    False
# structured_data_block_1/dense_block_1/dropout             0        0        0
# structured_data_block_1/dense_block_1/units_0            32       32       32
# structured_data_block_1/dense_block_1/units_1            32       32       32
# classification_head_1/dropout                           0.0      0.0      0.0
# optimizer                                              adam     adam     adam
# learning_rate                                         0.001    0.001    0.001
# score                                               0.70625  0.70625  0.70625
# structured_data_block_1/dense_block_1/units_2          1024       16       32
#
#                                                     trial#7  \
# structured_data_block_1/normalize                      True
# structured_data_block_1/dense_block_1/num_layers          3
# structured_data_block_1/dense_block_1/use_batch...     True
# structured_data_block_1/dense_block_1/dropout             0
# structured_data_block_1/dense_block_1/units_0            32
# structured_data_block_1/dense_block_1/units_1            32
# classification_head_1/dropout                           0.0
# optimizer                                              adam
# learning_rate                                         0.001
# score                                               0.65625
# structured_data_block_1/dense_block_1/units_2            32
#
#                                                               trial#8 trial#9  \
# structured_data_block_1/normalize                                True    True
# structured_data_block_1/dense_block_1/num_layers                    3       3
# structured_data_block_1/dense_block_1/use_batch...              False   False
# structured_data_block_1/dense_block_1/dropout                       0       0
# structured_data_block_1/dense_block_1/units_0                      32      32
# structured_data_block_1/dense_block_1/units_1                      32      32
# classification_head_1/dropout                                     0.0     0.0
# optimizer                                           adam_weight_decay    adam
# learning_rate                                                   0.001   0.001
# score                                                         0.64375  0.7125
# structured_data_block_1/dense_block_1/units_2                      32     256
#
#                                                    trial#10  ... trial#26  \
# structured_data_block_1/normalize                      True  ...     True
# structured_data_block_1/dense_block_1/num_layers          3  ...        3
# structured_data_block_1/dense_block_1/use_batch...    False  ...    False
# structured_data_block_1/dense_block_1/dropout             0  ...     0.25
# structured_data_block_1/dense_block_1/units_0            32  ...       32
# structured_data_block_1/dense_block_1/units_1            32  ...       32
# classification_head_1/dropout                           0.5  ...      0.5
# optimizer                                              adam  ...     adam
# learning_rate                                         0.001  ...    0.001
# score                                               0.71875  ...   0.7125
# structured_data_block_1/dense_block_1/units_2            32  ...       32
#
#                                                    trial#27 trial#28 trial#29  \
# structured_data_block_1/normalize                      True     True     True
# structured_data_block_1/dense_block_1/num_layers          3        3        3
# structured_data_block_1/dense_block_1/use_batch...    False    False    False
# structured_data_block_1/dense_block_1/dropout             0        0        0
# structured_data_block_1/dense_block_1/units_0           128       64      256
# structured_data_block_1/dense_block_1/units_1            32       32       32
# classification_head_1/dropout                           0.5      0.5      0.5
# optimizer                                              adam     adam     adam
# learning_rate                                         0.001    0.001    0.001
# score                                               0.70625  0.70625  0.70625
# structured_data_block_1/dense_block_1/units_2            32       32       32
#
#                                                    trial#30 trial#31 trial#32  \
# structured_data_block_1/normalize                      True     True     True
# structured_data_block_1/dense_block_1/num_layers          3        3        3
# structured_data_block_1/dense_block_1/use_batch...    False    False    False
# structured_data_block_1/dense_block_1/dropout             0        0        0
# structured_data_block_1/dense_block_1/units_0            32      512     1024
# structured_data_block_1/dense_block_1/units_1            32       32       32
# classification_head_1/dropout                           0.5      0.5      0.5
# optimizer                                              adam     adam     adam
# learning_rate                                         0.001    0.001    0.001
# score                                               0.70625  0.71875  0.70625
# structured_data_block_1/dense_block_1/units_2           512       32       32
#
#                                                              trial#33  \
# structured_data_block_1/normalize                                True
# structured_data_block_1/dense_block_1/num_layers                    3
# structured_data_block_1/dense_block_1/use_batch...              False
# structured_data_block_1/dense_block_1/dropout                       0
# structured_data_block_1/dense_block_1/units_0                      32
# structured_data_block_1/dense_block_1/units_1                      32
# classification_head_1/dropout                                     0.5
# optimizer                                           adam_weight_decay
# learning_rate                                                   0.001
# score                                                            0.65
# structured_data_block_1/dense_block_1/units_2                      32
#
#                                                    trial#34 trial#35
# structured_data_block_1/normalize                      True     True
# structured_data_block_1/dense_block_1/num_layers          3        3
# structured_data_block_1/dense_block_1/use_batch...    False    False
# structured_data_block_1/dense_block_1/dropout             0        0
# structured_data_block_1/dense_block_1/units_0            32       32
# structured_data_block_1/dense_block_1/units_1            32       32
# classification_head_1/dropout                           0.5      0.5
# optimizer                                              adam     adam
# learning_rate                                        0.0001    0.001
# score                                                0.7125  0.70625
# structured_data_block_1/dense_block_1/units_2            32       64
#
# [11 rows x 35 columns]
